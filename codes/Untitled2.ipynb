# %%
import train_unet
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_unet.train()
# Out:
# [data] load data shape data=(145, 145, 200), label=(145, 145)
# [data light split] data patches shape data=(25, 32, 32, 200), label=(25,)
# ------[data] after transpose train, test------
# X.shape= (25, 1, 200, 32, 32)
# Y.shape= (25,)
# [Epoch-step] 0 | step 000 Loss: 0.8024475574493408
# [TRAIN EPOCH 0] loss=0.8024475574493408
# --- 10 ---
# --- 60 ---
# --- 110 ---
# --- 160 ---
# --- 210 ---
# --- 260 ---
# --- 310 ---
# --- 360 ---
# --- 410 ---
# --- 460 ---
